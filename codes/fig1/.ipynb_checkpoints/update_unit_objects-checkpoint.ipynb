# %%
import os
import numpy as np
import pandas as pd
import pickle
from joblib import Parallel, delayed
import sys
sys.path.append('../')
from packages import actv_analysis
from packages.svm import SVM_fit
from packages.load_csv import units_for_svm

# Parameters
relus = range(2,6)
epochs = np.arange(0, 91, 10)
exps = np.arange(1, 11)
num_units = 100
rate_threshold = 0.05

# %%
def update_response_rate(units, actv, subset=False):
    non_zero_counts = np.count_nonzero(actv, axis=(1, 2))

    # Get the total number of elements in the second and third dimensions
    total_elements = actv.shape[1] * actv.shape[2]

    # Compute the response rate for each sample
    response_rates = (non_zero_counts / total_elements) * 100
    
    for i in range(len(units)):
        if subset:
            units[i].response_rate_subset = response_rates[i]
        else:
            units[i].response_rate = response_rates[i]
    
    return units

# %% [markdown]
# ## update response rate

# %%
min_sz_idx=3; max_sz_idx=9; numbers=np.arange(2,21,2); inst=500
take = np.arange(0,100).reshape(10,10)[:,min_sz_idx:max_sz_idx+1].reshape(len(numbers)*(max_sz_idx-min_sz_idx+1))

for net in range(1,11):
    for relu in range(2,6):
        for epoch in range(0,91,10):
            pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'
            if os.path.exists(pkl_filename):
                try:
                    with open(pkl_filename, 'rb') as f:
                        units = pickle.load(f)
                    print("Pickle file found.")
                    actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
                    actv_szAtoB = actv_net[:,take,:]
                    units = update_response_rate(units, actv_net, subset=False)
                    units = update_response_rate(units, actv_szAtoB, subset=True)
                    # Saving the updated units at the end of processing
                    with open(pkl_filename, 'wb') as f:
                        pickle.dump(units, f)
                    print(f'Successfully saved the updated units to {pkl_filename}')
                except Exception as e:
                    print(f"Pickle file {pkl_filename} failed to load due to error: {e}")

# %% [markdown]
# ## update monotonicity

# %%
min_sz_idx=3; max_sz_idx=9; numbers=np.arange(2,21,2); inst=500
take = np.arange(0,100).reshape(10,10)[:,min_sz_idx:max_sz_idx+1].reshape(len(numbers)*(max_sz_idx-min_sz_idx+1))

for net in range(1,11):
    for relu in range(2,6):
        for epoch in range(0,91,10):
            pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'
            if os.path.exists(pkl_filename):
                try:
                    with open(pkl_filename, 'rb') as f:
                        units = pickle.load(f)
                    print("Pickle file found.")
                    actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
                    actv_analysis.update_monotonicity(units, actv_net, subset=True)
                    # Saving the updated units at the end of processing
                    with open(pkl_filename, 'wb') as f:
                        pickle.dump(units, f)
                    print(f'Successfully saved the updated units to {pkl_filename}')
                except Exception as e:
                    print(f"Pickle file {pkl_filename} failed to load due to error: {e}")
# Out:
# Pickle file found.
# --- 359.7309799194336 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch0.pkl
# Pickle file found.
# --- 280.94770193099976 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch10.pkl
# Pickle file found.
# --- 276.15154004096985 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch20.pkl
# Pickle file found.
# --- 287.9196557998657 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch30.pkl
# Pickle file found.
# --- 307.7103338241577 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch40.pkl
# Pickle file found.
# --- 309.2399859428406 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch50.pkl
# Pickle file found.
# --- 316.6474521160126 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch60.pkl
# Pickle file found.
# --- 324.1111900806427 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch70.pkl
# Pickle file found.
# --- 326.87164187431335 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch80.pkl
# Pickle file found.
# --- 331.18216609954834 seconds ---
# Successfully saved the updated units to pkl/network1_Relu2_epoch90.pkl
# Pickle file found.
# --- 111.94867491722107 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch0.pkl
# Pickle file found.
# --- 66.88136196136475 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch10.pkl
# Pickle file found.
# --- 66.27210402488708 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch20.pkl
# Pickle file found.
# --- 65.42387318611145 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch30.pkl
# Pickle file found.
# --- 71.53519320487976 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch40.pkl
# Pickle file found.
# --- 76.2721598148346 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch50.pkl
# Pickle file found.
# --- 78.84644317626953 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch60.pkl
# Pickle file found.
# --- 82.86171889305115 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch70.pkl
# Pickle file found.
# --- 85.08752369880676 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch80.pkl
# Pickle file found.
# --- 85.82790994644165 seconds ---
# Successfully saved the updated units to pkl/network1_Relu3_epoch90.pkl
# Pickle file found.
# --- 108.5135543346405 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch0.pkl
# Pickle file found.
# --- 73.79757905006409 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch10.pkl
# Pickle file found.
# --- 73.03791785240173 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch20.pkl
# Pickle file found.
# --- 73.40713310241699 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch30.pkl
# Pickle file found.
# --- 81.45434594154358 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch40.pkl
# Pickle file found.
# --- 86.88099408149719 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch50.pkl
# Pickle file found.
# --- 89.40681076049805 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch60.pkl
# Pickle file found.
# --- 95.36840176582336 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch70.pkl
# Pickle file found.
# --- 94.25050187110901 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch80.pkl
# Pickle file found.
# --- 95.05240201950073 seconds ---
# Successfully saved the updated units to pkl/network1_Relu4_epoch90.pkl
# Pickle file found.
# --- 88.3578372001648 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch0.pkl
# Pickle file found.
# --- 52.57852268218994 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch10.pkl
# Pickle file found.
# --- 53.809048891067505 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch20.pkl
# Pickle file found.
# --- 54.47373414039612 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch30.pkl
# Pickle file found.
# --- 56.588143825531006 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch40.pkl
# Pickle file found.
# --- 56.35759115219116 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch50.pkl
# Pickle file found.
# --- 56.87491583824158 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch60.pkl
# Pickle file found.
# --- 56.44593811035156 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch70.pkl
# Pickle file found.
# --- 56.71502709388733 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch80.pkl
# Pickle file found.
# --- 57.95159578323364 seconds ---
# Successfully saved the updated units to pkl/network1_Relu5_epoch90.pkl
# Pickle file found.
# --- 362.4545419216156 seconds ---
# Successfully saved the updated units to pkl/network2_Relu2_epoch0.pkl
# Pickle file found.
# --- 117.45203304290771 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch0.pkl
# Pickle file found.
# --- 69.51508402824402 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch10.pkl
# Pickle file found.
# --- 66.03983998298645 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch20.pkl
# Pickle file found.
# --- 67.44037103652954 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch30.pkl
# Pickle file found.
# --- 71.79093194007874 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch40.pkl
# Pickle file found.
# --- 76.07891798019409 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch50.pkl
# Pickle file found.
# --- 78.72771000862122 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch60.pkl
# Pickle file found.
# --- 84.86757493019104 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch70.pkl
# Pickle file found.
# --- 86.72881412506104 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch80.pkl
# Pickle file found.
# --- 88.92445087432861 seconds ---
# Successfully saved the updated units to pkl/network2_Relu3_epoch90.pkl
# Pickle file found.
# --- 111.08986186981201 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch0.pkl
# Pickle file found.
# --- 78.07353401184082 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch10.pkl
# Pickle file found.
# --- 74.84816813468933 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch20.pkl
# Pickle file found.
# --- 74.47657799720764 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch30.pkl
# Pickle file found.
# --- 84.22459077835083 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch40.pkl
# Pickle file found.
# --- 93.08500504493713 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch50.pkl
# Pickle file found.
# --- 87.6019639968872 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch60.pkl
# Pickle file found.
# --- 93.83969712257385 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch70.pkl
# Pickle file found.
# --- 98.27588677406311 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch80.pkl
# Pickle file found.
# --- 99.92577028274536 seconds ---
# Successfully saved the updated units to pkl/network2_Relu4_epoch90.pkl
# Pickle file found.
# --- 87.20100998878479 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch0.pkl
# Pickle file found.
# --- 54.54498600959778 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch10.pkl
# Pickle file found.
# --- 55.24387884140015 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch20.pkl
# Pickle file found.
# --- 53.74671697616577 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch30.pkl
# Pickle file found.
# --- 56.39404797554016 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch40.pkl
# Pickle file found.
# --- 55.60985803604126 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch50.pkl
# Pickle file found.
# --- 57.200857639312744 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch60.pkl
# Pickle file found.
# --- 58.13317322731018 seconds ---
# Successfully saved the updated units to pkl/network2_Relu5_epoch70.pkl

# %%
min_sz_idx=3; max_sz_idx=9; numbers=np.arange(2,21,2); inst=500
take = np.arange(0,100).reshape(10,10)[:,min_sz_idx:max_sz_idx+1].reshape(len(numbers)*(max_sz_idx-min_sz_idx+1))

for net in range(1,3):
    for relu in range(2,6):
        for epoch in range(0,91,10):
            pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'
            if os.path.exists(pkl_filename):
                try:
                    with open(pkl_filename, 'rb') as f:
                        units = pickle.load(f)
                    print("Pickle file found.")
                    actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
                    actv_analysis.update_spearmanr(units, actv_net, subset=True)
                    # Saving the updated units at the end of processing
                    with open(pkl_filename, 'wb') as f:
                        pickle.dump(units, f)
                    print(f'Successfully saved the updated units to {pkl_filename}')
                except Exception as e:
                    print(f"Pickle file {pkl_filename} failed to load due to error: {e}")
