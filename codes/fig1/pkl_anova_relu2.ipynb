# %%
import numpy as np
import pandas as pd
import time
import sys
import os
import h5py
from joblib import Parallel, delayed
sys.path.append('../')
from packages import actv_analysis, svm, load_csv, stats, objects
import pickle
import re
import glob

# %%
for relu in range(2,6):
    for epoch in range(0,91,10):
        for net in range(1,11):
            stats.pkl_anova2_V2(net, relu, epoch, min_nidx=1, max_nidx=9)
# Out:
# Network1 Relu2 Epoch0
# Pickle file found.
# Network2 Relu2 Epoch0
# Pickle file found.
# Network3 Relu2 Epoch0
# Pickle file found.
# Network4 Relu2 Epoch0
# Pickle file found.
# Network5 Relu2 Epoch0
# Pickle file found.
# Network6 Relu2 Epoch0
# Pickle file found.
# Network7 Relu2 Epoch0
# Pickle file found.
# Network8 Relu2 Epoch0
# Pickle file found.
# Network9 Relu2 Epoch0
# Pickle file found.
# Network10 Relu2 Epoch0
# Pickle file found.
# Network1 Relu2 Epoch10
# Pickle file found.
# Network2 Relu2 Epoch10
# Pickle file found.
# Network3 Relu2 Epoch10
# Pickle file found.
# Network4 Relu2 Epoch10
# Pickle file found.
# Network5 Relu2 Epoch10
# Pickle file found.
# Network6 Relu2 Epoch10
# Pickle file found.
# Network7 Relu2 Epoch10
# Pickle file found.
# Network8 Relu2 Epoch10
# Pickle file found.
# Network9 Relu2 Epoch10
# Pickle file found.
# Network10 Relu2 Epoch10
# Pickle file found.
# Network1 Relu2 Epoch20
# Pickle file found.
# Network2 Relu2 Epoch20
# Pickle file found.
# Network3 Relu2 Epoch20
# Pickle file found.
# Network4 Relu2 Epoch20
# Pickle file found.
# Network5 Relu2 Epoch20
# Pickle file found.
# Network6 Relu2 Epoch20
# Pickle file found.
# Network7 Relu2 Epoch20
# Pickle file found.
# Network8 Relu2 Epoch20
# Pickle file found.
# Network9 Relu2 Epoch20
# Pickle file found.
# Network10 Relu2 Epoch20
# Pickle file found.
# Network1 Relu2 Epoch30
# Pickle file found.
# Network2 Relu2 Epoch30
# Pickle file found.
# Network3 Relu2 Epoch30
# Pickle file found.
# Network4 Relu2 Epoch30
# Pickle file found.
# Network5 Relu2 Epoch30
# Pickle file found.
# Network6 Relu2 Epoch30
# Pickle file found.
# Network7 Relu2 Epoch30
# Pickle file found.
# Network8 Relu2 Epoch30
# Pickle file found.
# Network9 Relu2 Epoch30
# Pickle file found.
# Network10 Relu2 Epoch30
# Pickle file found.
# Network1 Relu2 Epoch40
# Pickle file found.
# Network2 Relu2 Epoch40
# Pickle file found.
# Network3 Relu2 Epoch40
# Pickle file found.
# Network4 Relu2 Epoch40
# Pickle file found.
# Network5 Relu2 Epoch40
# Pickle file found.
# Network6 Relu2 Epoch40
# Pickle file found.
# Network7 Relu2 Epoch40
# Pickle file found.
# Network8 Relu2 Epoch40
# Pickle file found.
# Network9 Relu2 Epoch40
# Pickle file found.
# Network10 Relu2 Epoch40
# Pickle file found.
# Network1 Relu2 Epoch50
# Pickle file found.
# Network2 Relu2 Epoch50
# Pickle file found.
# Network3 Relu2 Epoch50
# Pickle file found.
# Network4 Relu2 Epoch50
# Pickle file found.
# Network5 Relu2 Epoch50
# Pickle file found.
# Network6 Relu2 Epoch50
# Pickle file found.
# Network7 Relu2 Epoch50
# Pickle file found.
# Network8 Relu2 Epoch50
# Pickle file found.
# Network9 Relu2 Epoch50
# Pickle file found.
# Network10 Relu2 Epoch50
# Pickle file found.
# Network1 Relu2 Epoch60
# Pickle file found.
# Network2 Relu2 Epoch60
# Pickle file found.
# Network3 Relu2 Epoch60
# Pickle file found.
# Network4 Relu2 Epoch60
# Pickle file found.
# Network5 Relu2 Epoch60
# Pickle file found.
# Network6 Relu2 Epoch60
# Pickle file found.
# Network7 Relu2 Epoch60
# Pickle file found.
# Network8 Relu2 Epoch60
# Pickle file found.
# Network9 Relu2 Epoch60
# Pickle file found.
# Network10 Relu2 Epoch60
# Pickle file found.
# Network1 Relu2 Epoch70
# Pickle file found.
# Network2 Relu2 Epoch70
# Pickle file found.
# Network3 Relu2 Epoch70
# Pickle file found.
# Network4 Relu2 Epoch70
# Pickle file found.
# Network5 Relu2 Epoch70
# Pickle file found.
# Network6 Relu2 Epoch70
# Pickle file found.
# Network7 Relu2 Epoch70
# Pickle file found.
# Network8 Relu2 Epoch70
# Pickle file found.
# Network9 Relu2 Epoch70
# Pickle file found.
# Network10 Relu2 Epoch70
# Pickle file found.
# Network1 Relu2 Epoch80
# Pickle file found.
# Network2 Relu2 Epoch80
# Pickle file found.
# Network3 Relu2 Epoch80
# Pickle file found.
# Network4 Relu2 Epoch80
# Pickle file found.
# Network5 Relu2 Epoch80
# Pickle file found.
# Network6 Relu2 Epoch80
# Pickle file found.
# Network7 Relu2 Epoch80
# Pickle file found.
# Network8 Relu2 Epoch80
# Pickle file found.
# Network9 Relu2 Epoch80
# Pickle file found.
# Network10 Relu2 Epoch80
# Pickle file found.
# Network1 Relu2 Epoch90
# Pickle file found.
# Network2 Relu2 Epoch90
# Pickle file found.
# Network3 Relu2 Epoch90
# Pickle file found.
# Network4 Relu2 Epoch90
# Pickle file found.
# Network5 Relu2 Epoch90
# Pickle file found.
# Network6 Relu2 Epoch90
# Pickle file found.
# Network7 Relu2 Epoch90
# Pickle file found.
# Network8 Relu2 Epoch90
# Pickle file found.
# Network9 Relu2 Epoch90
# Pickle file found.
# Network10 Relu2 Epoch90
# Pickle file found.
# Network1 Relu3 Epoch0
# Pickle file found.
# Network2 Relu3 Epoch0
# Pickle file found.
# Network3 Relu3 Epoch0
# Pickle file found.
# Network4 Relu3 Epoch0
# Pickle file found.
# Network5 Relu3 Epoch0
# Pickle file found.
# Network6 Relu3 Epoch0
# Pickle file found.
# Network7 Relu3 Epoch0
# Pickle file found.
# Network8 Relu3 Epoch0
# Pickle file found.
# Network9 Relu3 Epoch0
# Pickle file found.
# Network10 Relu3 Epoch0
# Pickle file found.
# Network1 Relu3 Epoch10
# Pickle file found.
# Network2 Relu3 Epoch10
# Pickle file found.
# Network3 Relu3 Epoch10
# Pickle file found.
# Network4 Relu3 Epoch10
# Pickle file found.
# Network5 Relu3 Epoch10
# Pickle file found.
# Network6 Relu3 Epoch10
# Pickle file found.
# Network7 Relu3 Epoch10
# Pickle file found.
# Network8 Relu3 Epoch10
# Pickle file found.
# Network9 Relu3 Epoch10
# Pickle file found.
# Network10 Relu3 Epoch10
# Pickle file found.
# Network1 Relu3 Epoch20
# Pickle file found.
# Network2 Relu3 Epoch20
# Pickle file found.
# Network3 Relu3 Epoch20
# Pickle file found.
# Network4 Relu3 Epoch20
# Pickle file found.
# Network5 Relu3 Epoch20
# Pickle file found.
# Network6 Relu3 Epoch20
# Pickle file found.
# Network7 Relu3 Epoch20
# Pickle file found.
# Network8 Relu3 Epoch20
# Pickle file found.
# Network9 Relu3 Epoch20
# Pickle file found.
# Network10 Relu3 Epoch20
# Pickle file found.
# Network1 Relu3 Epoch30
# Pickle file found.
# Network2 Relu3 Epoch30
# Pickle file found.
# Network3 Relu3 Epoch30
# Pickle file found.
# Network4 Relu3 Epoch30
# Pickle file found.
# Network5 Relu3 Epoch30
# Pickle file found.
# Network6 Relu3 Epoch30
# Pickle file found.
# Network7 Relu3 Epoch30
# Pickle file found.
# Network8 Relu3 Epoch30
# Pickle file found.
# Network9 Relu3 Epoch30
# Pickle file found.
# Network10 Relu3 Epoch30
# Pickle file found.
# Network1 Relu3 Epoch40
# Pickle file found.
# Network2 Relu3 Epoch40
# Pickle file found.
# Network3 Relu3 Epoch40
# Pickle file found.
# Network4 Relu3 Epoch40
# Pickle file found.
# Network5 Relu3 Epoch40
# Pickle file found.
# Network6 Relu3 Epoch40
# Pickle file found.
# Network7 Relu3 Epoch40
# Pickle file found.
# Network8 Relu3 Epoch40
# Pickle file found.
# Network9 Relu3 Epoch40
# Pickle file found.
# Network10 Relu3 Epoch40
# Pickle file found.
# Network1 Relu3 Epoch50
# Pickle file found.
# Network2 Relu3 Epoch50
# Pickle file found.
# Network3 Relu3 Epoch50
# Pickle file found.
# Network4 Relu3 Epoch50
# Pickle file found.
# Network5 Relu3 Epoch50
# Pickle file found.
# Network6 Relu3 Epoch50
# Pickle file found.
# Network7 Relu3 Epoch50
# Pickle file found.
# Network8 Relu3 Epoch50
# Pickle file found.
# Network9 Relu3 Epoch50
# Pickle file found.
# Network10 Relu3 Epoch50
# Pickle file found.
# Network1 Relu3 Epoch60
# Pickle file found.
# Network2 Relu3 Epoch60
# Pickle file found.
# Network3 Relu3 Epoch60
# Pickle file found.
# Network4 Relu3 Epoch60
# Pickle file found.
# Network5 Relu3 Epoch60
# Pickle file found.
# Network6 Relu3 Epoch60
# Pickle file found.
# Network7 Relu3 Epoch60
# Pickle file found.
# Network8 Relu3 Epoch60
# Pickle file found.
# Network9 Relu3 Epoch60
# Pickle file found.
# Network10 Relu3 Epoch60
# Pickle file found.
# Network1 Relu3 Epoch70
# Pickle file found.
# Network2 Relu3 Epoch70
# Pickle file found.
# Network3 Relu3 Epoch70
# Pickle file found.
# Network4 Relu3 Epoch70
# Pickle file found.
# Loading activity data to see if anova2 is complete.
# --- 80.90905284881592 seconds ---
# Updated no_response attributes of the units.
# Updated no_response_subset attributes of the units.
# Updated PN and PS attributes of the units.
# Updated response rates of the units.
# 75.33219313248257% units are incomplete!
# Starting with 3000 number of units at a time.
# Processing net 4, relu 3, epoch 70, block 1/16
# --- 212.55226016044617 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 2/16
# --- 209.12751507759094 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 3/16
# --- 206.1488790512085 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 4/16
# --- 208.5588390827179 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 5/16
# --- 206.64593887329102 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 6/16
# --- 206.99868512153625 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 7/16
# --- 206.11517119407654 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 8/16
# --- 205.94370579719543 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 9/16
# --- 207.1204891204834 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 10/16
# --- 207.80857491493225 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 11/16
# --- 210.2287790775299 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 12/16
# --- 208.84304308891296 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 13/16
# --- 207.13037204742432 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 14/16
# --- 207.26912093162537 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 15/16
# --- 208.56400108337402 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Processing net 4, relu 3, epoch 70, block 16/16
# --- 57.148985147476196 seconds ---
# Successfully saved the updated units to pkl/4to20/network4_Relu3_epoch70_4to20.pkl
# Successfully saved the updated units to csv/network4_Relu3_epoch70_obj_4to20.csv
# Network5 Relu3 Epoch70
# Pickle file found.
# Network6 Relu3 Epoch70
# Pickle file found.
# Network7 Relu3 Epoch70
# Pickle file found.
# Network8 Relu3 Epoch70
# Pickle file found.
# Network9 Relu3 Epoch70
# Pickle file found.
# Network10 Relu3 Epoch70
# Pickle file found.
# Network1 Relu3 Epoch80
# Pickle file found.
# Network2 Relu3 Epoch80
# Pickle file found.
# Network3 Relu3 Epoch80
# Pickle file found.
# Network4 Relu3 Epoch80
# Pickle file found.
# Network5 Relu3 Epoch80
# Pickle file found.
# Network6 Relu3 Epoch80
# Pickle file found.
# Network7 Relu3 Epoch80
# Pickle file found.
# Network8 Relu3 Epoch80
# Pickle file found.
# Network9 Relu3 Epoch80
# Pickle file found.
# Network10 Relu3 Epoch80
# Pickle file found.
# Network1 Relu3 Epoch90
# Pickle file found.
# Network2 Relu3 Epoch90
# Pickle file found.
# Network3 Relu3 Epoch90
# Pickle file found.
# Network4 Relu3 Epoch90
# Pickle file found.
# Network5 Relu3 Epoch90
# Pickle file found.
# Network6 Relu3 Epoch90
# Pickle file found.
# Network7 Relu3 Epoch90
# Pickle file found.
# Network8 Relu3 Epoch90
# Pickle file found.
# Network9 Relu3 Epoch90
# Pickle file found.
# Network10 Relu3 Epoch90
# Pickle file found.
# Network1 Relu4 Epoch0
# Pickle file found.
# Network2 Relu4 Epoch0
# Pickle file found.
# Network3 Relu4 Epoch0
# Pickle file found.
# Network4 Relu4 Epoch0
# Pickle file found.
# Network5 Relu4 Epoch0
# Pickle file found.
# Network6 Relu4 Epoch0
# Pickle file found.
# Network7 Relu4 Epoch0
# Pickle file found.
# Network8 Relu4 Epoch0
# Pickle file found.
# Network9 Relu4 Epoch0
# Pickle file found.
# Network10 Relu4 Epoch0
# Pickle file found.
# Network1 Relu4 Epoch10
# Pickle file found.
# Network2 Relu4 Epoch10
# Pickle file found.
# Network3 Relu4 Epoch10
# Pickle file found.
# Network4 Relu4 Epoch10
# Pickle file found.
# Network5 Relu4 Epoch10
# Pickle file found.
# Network6 Relu4 Epoch10
# Pickle file found.
# Network7 Relu4 Epoch10
# Pickle file found.
# Network8 Relu4 Epoch10
# Pickle file found.
# Network9 Relu4 Epoch10
# Pickle file found.
# Network10 Relu4 Epoch10
# Pickle file found.
# Network1 Relu4 Epoch20
# Pickle file found.
# Network2 Relu4 Epoch20
# Pickle file found.
# Network3 Relu4 Epoch20
# Pickle file found.
# Network4 Relu4 Epoch20
# Pickle file found.
# Network5 Relu4 Epoch20
# Pickle file found.
# Loading activity data to see if anova2 is complete.
# --- 73.51560807228088 seconds ---
# Updated no_response attributes of the units.
# Updated no_response_subset attributes of the units.
# Updated PN and PS attributes of the units.
# Updated response rates of the units.
# 57.91311396193475% units are incomplete!
# Starting with 3000 number of units at a time.
# Processing net 5, relu 4, epoch 20, block 1/13
# --- 211.78783988952637 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 2/13
# --- 210.02468705177307 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 3/13
# --- 211.09870600700378 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 4/13
# --- 209.92253804206848 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 5/13
# --- 211.05120515823364 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 6/13
# --- 210.5445921421051 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 7/13
# --- 209.50520491600037 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 8/13
# --- 209.8939709663391 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 9/13
# --- 210.5303361415863 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 10/13
# --- 210.3086998462677 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 11/13
# --- 212.2243571281433 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 12/13
# --- 212.58753418922424 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Processing net 5, relu 4, epoch 20, block 13/13
# --- 83.56778597831726 seconds ---
# Successfully saved the updated units to pkl/4to20/network5_Relu4_epoch20_4to20.pkl
# Successfully saved the updated units to csv/network5_Relu4_epoch20_obj_4to20.csv
# Network6 Relu4 Epoch20
# Pickle file found.
# Network7 Relu4 Epoch20
# Pickle file found.
# Network8 Relu4 Epoch20
# Pickle file found.
# Network9 Relu4 Epoch20
# Pickle file found.
# Network10 Relu4 Epoch20
# Pickle file found.
# Network1 Relu4 Epoch30
# Pickle file found.
# Network2 Relu4 Epoch30
# Pickle file found.
# Network3 Relu4 Epoch30
# Pickle file found.
# Network4 Relu4 Epoch30
# Pickle file found.
# Network5 Relu4 Epoch30
# Pickle file found.
# Network6 Relu4 Epoch30
# Pickle file found.
# Network7 Relu4 Epoch30
# Pickle file found.
# Network8 Relu4 Epoch30
# Pickle file found.
# Network9 Relu4 Epoch30
# Pickle file found.
# Network10 Relu4 Epoch30
# Pickle file found.
# Network1 Relu4 Epoch40
# Pickle file found.
# Network2 Relu4 Epoch40
# Pickle file found.
# Network3 Relu4 Epoch40
# Pickle file found.
# Network4 Relu4 Epoch40
# Pickle file found.
# Network5 Relu4 Epoch40
# Pickle file found.
# Network6 Relu4 Epoch40
# Pickle file found.
# Network7 Relu4 Epoch40
# Pickle file found.
# Network8 Relu4 Epoch40
# Pickle file found.
# Network9 Relu4 Epoch40
# Pickle file found.
# Network10 Relu4 Epoch40
# Pickle file found.
# Network1 Relu4 Epoch50
# Pickle file found.
# Network2 Relu4 Epoch50
# Pickle file found.
# Network3 Relu4 Epoch50
# Pickle file found.
# Network4 Relu4 Epoch50
# Pickle file found.
# Network5 Relu4 Epoch50
# Pickle file found.
# Network6 Relu4 Epoch50
# Pickle file found.
# Network7 Relu4 Epoch50
# Pickle file found.
# Network8 Relu4 Epoch50
# Pickle file found.
# Network9 Relu4 Epoch50
# Pickle file found.
# Network10 Relu4 Epoch50
# Pickle file found.
# Network1 Relu4 Epoch60
# Pickle file found.
# Network2 Relu4 Epoch60
# Pickle file found.
# Network3 Relu4 Epoch60
# Pickle file found.
# Network4 Relu4 Epoch60
# Pickle file found.
# Network5 Relu4 Epoch60
# Pickle file found.
# Network6 Relu4 Epoch60
# Pickle file found.
# Network7 Relu4 Epoch60
# Pickle file found.
# Network8 Relu4 Epoch60
# Pickle file found.
# Network9 Relu4 Epoch60
# Pickle file found.
# Network10 Relu4 Epoch60
# Pickle file found.
# Network1 Relu4 Epoch70
# Pickle file found.
# Network2 Relu4 Epoch70
# Pickle file found.
# Network3 Relu4 Epoch70
# Pickle file found.
# Network4 Relu4 Epoch70
# Pickle file found.
# Network5 Relu4 Epoch70
# Pickle file found.
# Network6 Relu4 Epoch70
# Pickle file found.
# Network7 Relu4 Epoch70
# Pickle file found.
# Network8 Relu4 Epoch70
# Pickle file found.
# Network9 Relu4 Epoch70
# Pickle file found.
# Network10 Relu4 Epoch70
# Pickle file found.
# Network1 Relu4 Epoch80
# Pickle file found.
# Network2 Relu4 Epoch80
# Pickle file found.
# Network3 Relu4 Epoch80
# Pickle file found.
# Network4 Relu4 Epoch80
# Pickle file found.
# Network5 Relu4 Epoch80
# Pickle file found.
# Network6 Relu4 Epoch80
# Pickle file found.
# Network7 Relu4 Epoch80
# Pickle file found.
# Network8 Relu4 Epoch80
# Pickle file found.
# Network9 Relu4 Epoch80
# Pickle file found.
# Network10 Relu4 Epoch80
# Pickle file found.
# Network1 Relu4 Epoch90
# Pickle file found.
# Network2 Relu4 Epoch90
# Pickle file found.
# Network3 Relu4 Epoch90
# Pickle file found.
# Network4 Relu4 Epoch90
# Pickle file found.
# Network5 Relu4 Epoch90
# Pickle file found.
# Network6 Relu4 Epoch90
# Pickle file found.
# Network7 Relu4 Epoch90
# Pickle file found.
# Network8 Relu4 Epoch90
# Pickle file found.
# Network9 Relu4 Epoch90
# Pickle file found.
# Network10 Relu4 Epoch90
# Pickle file found.
# Network1 Relu5 Epoch0
# Pickle file found.
# Network2 Relu5 Epoch0
# Pickle file found.
# Network3 Relu5 Epoch0
# Pickle file found.
# Network4 Relu5 Epoch0
# Pickle file found.
# Network5 Relu5 Epoch0
# Pickle file found.
# Network6 Relu5 Epoch0
# Pickle file found.
# Network7 Relu5 Epoch0
# Pickle file found.
# Network8 Relu5 Epoch0
# Pickle file found.
# Network9 Relu5 Epoch0
# Pickle file found.
# Network10 Relu5 Epoch0
# Pickle file found.
# Network1 Relu5 Epoch10
# Pickle file found.
# Network2 Relu5 Epoch10
# Pickle file found.
# Network3 Relu5 Epoch10
# Pickle file found.
# Network4 Relu5 Epoch10
# Pickle file found.
# Network5 Relu5 Epoch10
# Pickle file found.
# Network6 Relu5 Epoch10
# Pickle file found.
# Network7 Relu5 Epoch10
# Pickle file found.
# Network8 Relu5 Epoch10
# Pickle file found.
# Network9 Relu5 Epoch10
# Pickle file found.
# Network10 Relu5 Epoch10
# Pickle file found.
# Network1 Relu5 Epoch20
# Pickle file found.
# Network2 Relu5 Epoch20
# Pickle file found.
# Network3 Relu5 Epoch20
# Pickle file found.
# Network4 Relu5 Epoch20
# Pickle file found.
# Network5 Relu5 Epoch20
# Pickle file found.
# Network6 Relu5 Epoch20
# Pickle file found.
# Network7 Relu5 Epoch20
# Pickle file found.
# Network8 Relu5 Epoch20
# Pickle file found.
# Network9 Relu5 Epoch20
# Pickle file found.
# Network10 Relu5 Epoch20
# Pickle file found.
# Network1 Relu5 Epoch30
# Pickle file found.
# Network2 Relu5 Epoch30
# Pickle file found.
# Network3 Relu5 Epoch30
# Pickle file found.
# Network4 Relu5 Epoch30
# Pickle file found.
# Network5 Relu5 Epoch30
# Pickle file found.
# Network6 Relu5 Epoch30
# Pickle file found.
# Network7 Relu5 Epoch30
# Pickle file found.
# Network8 Relu5 Epoch30
# Pickle file found.
# Network9 Relu5 Epoch30
# Pickle file found.
# Network10 Relu5 Epoch30
# Pickle file found.
# Network1 Relu5 Epoch40
# Pickle file found.
# Network2 Relu5 Epoch40
# Pickle file found.
# Network3 Relu5 Epoch40
# Pickle file found.
# Network4 Relu5 Epoch40
# Pickle file found.
# Network5 Relu5 Epoch40
# Pickle file found.
# Network6 Relu5 Epoch40
# Pickle file found.
# Network7 Relu5 Epoch40
# Pickle file found.
# Network8 Relu5 Epoch40
# Pickle file found.
# Network9 Relu5 Epoch40
# Pickle file found.
# Network10 Relu5 Epoch40
# Pickle file found.
# Network1 Relu5 Epoch50
# Pickle file found.
# Network2 Relu5 Epoch50
# Pickle file found.
# Network3 Relu5 Epoch50
# Pickle file found.
# Network4 Relu5 Epoch50
# Pickle file found.
# Network5 Relu5 Epoch50
# Pickle file found.
# Network6 Relu5 Epoch50
# Pickle file found.
# Network7 Relu5 Epoch50
# Pickle file found.
# Network8 Relu5 Epoch50
# Pickle file found.
# Network9 Relu5 Epoch50
# Pickle file found.
# Network10 Relu5 Epoch50
# Pickle file found.
# Network1 Relu5 Epoch60
# Pickle file found.
# Network2 Relu5 Epoch60
# Pickle file found.
# Network3 Relu5 Epoch60
# Pickle file found.
# Network4 Relu5 Epoch60
# Pickle file found.
# Network5 Relu5 Epoch60
# Pickle file found.
# Network6 Relu5 Epoch60
# Pickle file found.
# Network7 Relu5 Epoch60
# Pickle file found.
# Network8 Relu5 Epoch60
# Pickle file found.
# Network9 Relu5 Epoch60
# Pickle file found.
# Network10 Relu5 Epoch60
# Pickle file found.
# Network1 Relu5 Epoch70
# Pickle file found.
# Network2 Relu5 Epoch70
# Pickle file found.
# Network3 Relu5 Epoch70
# Pickle file found.
# Network4 Relu5 Epoch70
# Pickle file found.
# Network5 Relu5 Epoch70
# Pickle file found.
# Network6 Relu5 Epoch70
# Pickle file found.
# Network7 Relu5 Epoch70
# Pickle file found.
# Network8 Relu5 Epoch70
# Pickle file found.
# Network9 Relu5 Epoch70
# Pickle file found.
# Network10 Relu5 Epoch70
# Pickle file found.
# Network1 Relu5 Epoch80
# Pickle file found.
# Network2 Relu5 Epoch80
# Pickle file found.
# Network3 Relu5 Epoch80
# Pickle file found.
# Network4 Relu5 Epoch80
# Pickle file found.
# Network5 Relu5 Epoch80
# Pickle file found.
# Network6 Relu5 Epoch80
# Pickle file found.
# Network7 Relu5 Epoch80
# Pickle file found.
# Network8 Relu5 Epoch80
# Pickle file found.
# Network9 Relu5 Epoch80
# Pickle file found.
# Network10 Relu5 Epoch80
# Pickle file found.
# Network1 Relu5 Epoch90
# Pickle file found.
# Network2 Relu5 Epoch90
# Pickle file found.
# Network3 Relu5 Epoch90
# Pickle file found.
# Network4 Relu5 Epoch90
# Pickle file found.
# Network5 Relu5 Epoch90
# Pickle file found.
# Network6 Relu5 Epoch90
# Pickle file found.
# Network7 Relu5 Epoch90
# Pickle file found.
# Network8 Relu5 Epoch90
# Pickle file found.
# Network9 Relu5 Epoch90
# Pickle file found.
# Network10 Relu5 Epoch90
# Pickle file found.

# %% [markdown]
# #### units[13].no_response

# %%
avg_actv = np.nanmean(actv_net, axis=2)
avg_actv_nxs_ = avg_actv.reshape(actv_net.shape[0], len(numbers), len(sizes))
avg_actv_nxs = avg_actv_nxs_[:,:,min_sz_idx:max_sz_idx+1]

# %%
np.argmax(avg_actv_nxs,axis=1).shape

# %%
numbers[np.argmax(np.mean(avg_actv_nxs,axis=2),axis=1)]

# %%
incomplete_units = np.setdiff1d(incomplete_units, anova2_failed)

# %%
incomplete_units

# %%
import pandas as pd
import statsmodels.api as sm
print("Pandas version: ", pd.__version__)
print("Statsmodels version: ", sm.__version__)

# %%
df_test = pd.DataFrame({
    'number': [1, 2, 3, 1, 2, 3, 1, 2, 3],  # dummy variable number
    'size': [1, 1, 1, 2, 2, 2, 3, 3, 3],  # dummy variable size
    'activity': [1, 2, 3, 4, 5, 6, 7, 8, 9]  # arbitrary activity values
})

# Fitting the OLS model:
from statsmodels.formula.api import ols
model_test = ols('activity ~ C(number) + C(size) + C(number):C(size)', data=df_test).fit()

# Running the ANOVA test:
from statsmodels.stats.anova import anova_lm
stat_test = anova_lm(model_test, typ=2)
print(stat_test)

# %%
units[0].anova2

# %%
actv_net = actv_analysis.get_actv_net(net=1,relu=3,epoch=0)

# %%
actv_net.shape
